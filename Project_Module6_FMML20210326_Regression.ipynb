# %% [markdown]
# <a href="https://colab.research.google.com/github/venkat52/my_colab_notes/blob/main/Project_Module6_FMML20210326_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Module 6 Project: Covid Data Analysis with Regression

# %% [markdown]
# `Module Coordinator: Pranav Tadimeti`

# %% [markdown]
# In this project, we will use the concepts of regression and regularization we have learnt to predict early Covid-19 cases. We shall use linear regression, polynomial regression and ridge regression to obtain a reasonably good estimate of the future cases. Try experimenting with hyperparameters to obtain better results.

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# ### 1. **Load the data** into a pandas dataframe.

# %%
# Imports
import pandas as pd
import numpy  as np
import scipy.integrate

from matplotlib import pyplot as plt
plt.style.use('ggplot')
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 10, 8

import copy
from   sklearn.metrics       import mean_squared_error, mean_absolute_error
from   sklearn.linear_model  import LinearRegression, BayesianRidge
from   sklearn.tree          import DecisionTreeRegressor
from   sklearn.preprocessing import PolynomialFeatures

# %%
path = "https://raw.githubusercontent.com/PranavTadimeti/Regression_Project/main/covid_19_data.csv"
df_orig = pd.read_csv(path)
print(df_orig.head())
# Out:
#    SNo ObservationDate Province/State  Country/Region      Last Update  \
# 0    1      01/22/2020          Anhui  Mainland China  1/22/2020 17:00
# 1    2      01/22/2020        Beijing  Mainland China  1/22/2020 17:00
# 2    3      01/22/2020      Chongqing  Mainland China  1/22/2020 17:00
# 3    4      01/22/2020         Fujian  Mainland China  1/22/2020 17:00
# 4    5      01/22/2020          Gansu  Mainland China  1/22/2020 17:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# 4        0.0     0.0        0.0

# %% [markdown]
# ### 2. Create a new dataframe which counts the cumulative total number of cases, the cumulative total number of deaths, and also  cumulative total number of recoveries for each date.

# %%
df = copy.deepcopy(df_orig)
df.drop('Last Update',inplace=True,axis=1)
date_lst  = df.ObservationDate.unique()
date_dict = {}

for i in range(len(date_lst)):
    df_temp = df.loc[df['ObservationDate'] == date_lst[i]]
    date_dict[date_lst[i]] = df_temp

# %%
date_tot_tup_dict = {};
for date, df in date_dict.items():
    tup_temp = (df['Confirmed'].sum(), df['Deaths'].sum(), df['Recovered'].sum())
    date_tot_tup_dict[date] = tup_temp

# %%
df_date_tots = pd.DataFrame(date_tot_tup_dict)
df_date_tots = df_date_tots.transpose()
df_date_tots.columns = ['Confirmed', 'Deaths', 'Recovered']
print(df_date_tots)
# Out:
#             Confirmed   Deaths  Recovered
# 01/22/2020      555.0     17.0       28.0
# 01/23/2020      653.0     18.0       30.0
# 01/24/2020      941.0     26.0       36.0
# 01/25/2020     1438.0     42.0       39.0
# 01/26/2020     2118.0     56.0       52.0
# ...               ...      ...        ...
# 03/27/2020   593291.0  27198.0   130915.0
# 03/28/2020   660706.0  30652.0   139415.0
# 03/29/2020   720117.0  33925.0   149082.0
# 03/30/2020   782365.0  37582.0   164566.0
# 03/31/2020   857487.0  42107.0   178034.0
#
# [70 rows x 3 columns]

# %% [markdown]
# ### 3. **Plot** the total number of cases per day over time and summarize findings

# %%
plt.figure(figsize = [15,5])
plt.plot(df_date_tots['Confirmed'], label = "Confirmed Cases")
plt.plot(df_date_tots['Deaths'], label    = "Deaths")
plt.plot(df_date_tots['Recovered'], label = "Recovered Cases")

plt.legend()
plt.xlabel("Day")
plt.ylabel("Count")
plt.xticks(rotation = 90);
start_date = str(date_lst[0]);
fin_date   = str(date_lst[len(date_lst) -1])
plt.title("Total Cases, Deaths, and Recoveries : " + start_date + " - " + fin_date);

# %% [markdown]
# All of the three curves seem to be exponential (start of logistic curve). The confirmed cases was obviously higher than the deaths and recovered cases. The rate of the the recovered cases seems to be higher than that of the death curve.

# %% [markdown]
# ### 4. Create a new column in the dataframe called **“closed cases”**

# %%
df_date_tots['Closed Cases'] = df_date_tots['Deaths'] + df_date_tots['Recovered']

# %% [markdown]
# ### 5. Create a new column in the dataframe called “active cases”

# %%
df_date_tots['Active Cases'] = df_date_tots['Confirmed'] - df_date_tots['Closed Cases']

# %% [markdown]
# ### 6. Create one **plot** showing the trend of number of active cases and closed cases

# %%
plt.figure(figsize = [15,5])
plt.plot(df_date_tots['Active Cases'], label = "Active Cases")
plt.plot(df_date_tots['Closed Cases'], label = "Closed Cases")

plt.legend();
plt.xlabel("Day")
plt.ylabel("Count")
plt.xticks(rotation = 90)
start_date = str(date_lst[0])
fin_date   = str(date_lst[len(date_lst) -1])
plt.title("Active Cases vs Closed Cases COVID-19 : " + start_date + " - " + fin_date);

# %% [markdown]
# The number of active cases is higher than the number of closed cases as of yet.

# %% [markdown]
# ### 7. Growth Factor

# %%
growth_len_lst = len(date_lst) - 1
confirmed_lst = df_date_tots["Confirmed"]
death_lst = df_date_tots["Deaths"]
recovered_lst = df_date_tots["Recovered"]
confGF_lst = []
deathsGF_lst = []
recovGF_lst = []
for i in range(growth_len_lst):
    confirmedGF = confirmed_lst[i+1] / confirmed_lst[i] 
    confGF_lst.append(confirmedGF)
    deathGF = death_lst[i+1] / death_lst[i] 
    deathsGF_lst.append(deathGF)
    recoveredGF = recovered_lst[i+1] / recovered_lst[i] 
    recovGF_lst.append(recoveredGF);

# %%
plt.figure(figsize = [15,5])
plt.plot(confGF_lst, label = "Growth Factor of Confirmed Cases")
plt.plot(deathsGF_lst, label = "Growth Factor of Deaths")
plt.plot(recovGF_lst, label = "Growth Factor of Recovered Cases")
x = []
for i in range((growth_len_lst)):
    x.append(1)
plt.plot(x, label = "Growth Factor = 1.0")

#plt.grid()
plt.legend()
plt.xlabel("Day")
plt.ylabel("Growth Ratio")
plt.ylim(.5,2)
plt.xticks(rotation = 90)
start_date = str(date_lst[0])
fin_date   = str(date_lst[len(date_lst) -1])
plt.title("Growth Factors of Confirmed, Death, and Recovered Cases COVID-19 : " +start_date +" - " +fin_date)
# Out:
# Text(0.5, 1.0, 'Growth Factors of Confirmed, Death, and Recovered Cases COVID-19 : 01/22/2020 - 03/31/2020')

# %% [markdown]
# # **Part 2 - Prediction Using Linear Regression**

# %% [markdown]
# #### To make our data to be compatible with *sklearn* format, create a new column called “Days since” which tracks the number of days since the initial date.

# %%
days_since_lst = []
for i in range(len(date_lst)):
    days_since_lst.append(i)
df_date_tots["Days Since:"] = days_since_lst
df_date_tots = df_date_tots[["Days Since:", "Confirmed", "Deaths", "Recovered", "Active Cases", "Closed Cases"]]

# %% [markdown]
# ### 8. Take the earliest 85% of the dates as **train** and the rest as **test**

# %%
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler

X = np.array(df_date_tots["Days Since:"]).reshape(-1,1)
y = np.array(df_date_tots["Confirmed"])

# %%
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    test_size = 0.15,
                                                    shuffle = False)

# %% [markdown]
# ### 9. We can try different regression and regularizations we have seen before

# %% [markdown]
# #### 9.1 Linear Regression

# %%
lin_model = LinearRegression(fit_intercept = False)
lin_model.fit(X_train, y_train)
test_lin_pred = lin_model.predict(X_test)
lin_pred = lin_model.predict(X)

# %%
plt.figure(figsize = [15,5])
# plotting the actual values for the future days
plt.plot(X_test,
         y_test,
         label = "Actual Confirmed Cases")
# plotting the predicited values for the future days
plt.plot(X_test,
         test_lin_pred,
         label = "Lin Regression predicted Confirmed Cases")
plt.grid();
plt.legend();
plt.xlabel("Day", size = 25)
plt.ylabel("Count", size = 25)
plt.xticks(rotation = 90, size = 15)
plt.show()

print('MAE:', mean_absolute_error (test_lin_pred, X_test))
print('MSE:', mean_squared_error  (test_lin_pred, X_test))
# Out:
# MAE: 181791.423099402
# MSE: 33128805402.917187

# %% [markdown]
# #### Polynomial Regression

# %%
poly = PolynomialFeatures(degree=5)
poly_X_train = poly.fit_transform(X_train)
poly_X_test  = poly.fit_transform(X_test)
poly_X = poly.fit_transform(X)

# %%
linear_model = LinearRegression(fit_intercept=False)
linear_model.fit(poly_X_train, y_train)
test_poly_pred = linear_model.predict(poly_X_test)
poly_pred = linear_model.predict(poly_X)

# %%
plt.figure(figsize = [15,5])

# plotting the actual values for the future days
plt.plot(X_test,
         y_test,
         label = "Actual Confirmed Cases")

# plotting the predicited values for the future days
plt.plot(X_test,
         test_poly_pred,
         label = "Polynomial Regression Confirmed Cases")
plt.grid();
plt.legend();
plt.xlabel("Day", size = 25)
plt.ylabel("Count", size = 25)
plt.xticks(rotation = 90, size = 15);
plt.show()

print('MAE:', mean_absolute_error(test_poly_pred, y_test))
print('MSE:',mean_squared_error(test_poly_pred, y_test))
# Out:
# MAE: 31989.752678661967
# MSE: 1314905592.3565953

# %%
plt.figure(figsize=(15, 5))
plt.plot(X,
         y,
         label = 'Actual Future Cases')

plt.plot(X,
         poly_pred,
         label = 'Polynomial Regression Prediction of Future Cases',
         linestyle = "dashed")

plt.plot(X_train,
         y_train,
         label = 'Training Cases')

plt.xlabel('Days Since', size = 30)
plt.ylabel('# of Cases', size = 30)
plt.legend()
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

# %% [markdown]
# ### 9.2 Ridge Regression

# %%
tol      = [1e-4, 1e-3, 1e-2]
alpha_1  = [1e-7, 1e-6, 1e-5, 1e-4]
alpha_2  = [1e-7, 1e-6, 1e-5, 1e-4]
lambda_1 = [1e-7, 1e-6, 1e-5, 1e-4]
lambda_2 = [1e-7, 1e-6, 1e-5, 1e-4]

bayesian_grid = {'tol': tol,
                 'alpha_1': alpha_1,
                 'alpha_2' : alpha_2,
                 'lambda_1': lambda_1,
                 'lambda_2' : lambda_2 }

bayesian = BayesianRidge(fit_intercept=False)
bayesian_search = RandomizedSearchCV(bayesian,
                                     bayesian_grid,
                                     scoring='neg_mean_squared_error',
                                     cv=3,
                                     return_train_score=True,
                                     n_jobs=-1,
                                     n_iter=40,
                                     verbose=1)

bayesian_search.fit(X_train, y_train)

print(bayesian_search.best_params_)
# Out:
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# {'tol': 0.0001, 'lambda_2': 1e-07, 'lambda_1': 0.0001, 'alpha_2': 1e-07, 'alpha_1': 1e-07}

# %%
y_test_ridge_pred = bayesian_search.predict(X_test);
y_ridge_pred = bayesian_search.predict(X);

# %%
plt.figure(figsize = [15,5])

# plotting the actual values for the future days
plt.plot(X_test,
         y_test,
         label = "Actual Confirmed Cases")

# plotting the predicited values for the future days
plt.plot(X_test,
         y_test_ridge_pred,
         label = "Ridge predicted Confirmed Cases")
plt.grid();
plt.legend();
plt.xlabel("Day", size = 25)
plt.ylabel("Count", size = 25)
plt.xticks(rotation = 90, size = 15);
plt.show()

print('MAE:', mean_absolute_error (y_test_ridge_pred, X_test))
print('MSE:', mean_squared_error  (y_test_ridge_pred, X_test))
# Out:
# MAE: 181588.76120723973
# MSE: 33054982293.94005

# %%
plt.figure(figsize=(15, 5))
plt.plot(X,
         y,
         label = 'Actual Future Cases')
plt.plot(X,
         y_ridge_pred,
         label = 'Ridge Prediction of Future Cases',
         linestyle = "dashed")
plt.plot(X_train,
         y_train,
         label = 'Training Cases')

#plt.title('# of Coronavirus Cases Over Time', size=30)
plt.xlabel('Days Since', size = 30)
plt.ylabel('# of Cases', size = 30)
plt.legend()
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

# %% [markdown]
# #### Polynomial Ridge Regression

# %%
bayesian_search_poly = RandomizedSearchCV(bayesian,
                                     bayesian_grid,
                                     scoring='neg_mean_squared_error',
                                     cv=3,
                                     return_train_score=True,
                                     n_jobs=-1,
                                     n_iter=40,
                                     verbose=1)

# %%
bayesian_search_poly.fit(poly_X_train, y_train);
print(bayesian_search_poly.best_params_)
# Out:
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# {'tol': 0.0001, 'lambda_2': 0.0001, 'lambda_1': 1e-06, 'alpha_2': 0.0001, 'alpha_1': 1e-06}

# %%
bayesian_poly_confirmed = bayesian_search_poly.best_estimator_
test_poly_bayesian_pred = bayesian_poly_confirmed.predict(poly_X_test)
bayesian_poly_pred = bayesian_poly_confirmed.predict(poly_X)

# %%
plt.figure(figsize = [15,5])

# plotting the actual values for the future days
plt.plot(X_test,
         y_test,
         label = "Actual Confirmed Cases")

# plotting the predicited values for the future days
plt.plot(X_test,
         test_poly_bayesian_pred,
         label = "Ridge Polynomial predicted Confirmed Cases")
plt.grid();
plt.legend();
plt.xlabel("Day", size = 25)
plt.ylabel("Count", size = 25)
plt.xticks(rotation = 90, size = 15)
plt.show()

print ('MAE:', mean_absolute_error(test_poly_bayesian_pred, y_test))
print ('MSE:', mean_squared_error (test_poly_bayesian_pred, y_test))
# Out:
# MAE: 15796.249691585459
# MSE: 352570947.93456024

# %%
plt.figure(figsize=(15, 5))
plt.plot(X,
         y,
         label = 'Actual Future Cases')
plt.plot(X,
         bayesian_poly_pred,
         label = 'Ridge Polynomial Prediction of Future Cases',
         linestyle = "dashed")
plt.plot(X_train,
         y_train,
         label = 'Training Cases')

#plt.title('# of Coronavirus Cases Over Time', size=30)
plt.xlabel('Days Since', size = 30)
plt.ylabel('# of Cases', size = 30)
#plt.grid()
plt.legend()
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

# %%
print("Polynomial Regression ")
print('\tMAE:', mean_absolute_error(test_poly_pred, y_test))
print('\tMSE:',mean_squared_error(test_poly_pred, y_test))

print("\nRidge Polynomial Regression ")
print ('\tMAE:', mean_absolute_error(test_poly_bayesian_pred, y_test))
print ('\tMSE:', mean_squared_error (test_poly_bayesian_pred, y_test))
# Out:
# Polynomial Regression
# 	MAE: 31989.752678661967
# 	MSE: 1314905592.3565953
#
# Ridge Polynomial Regression
# 	MAE: 15796.249691585459
# 	MSE: 352570947.93456024

# %% [markdown]
# From Mean Absolute Error and Mean Squared Error values, Ridge Polynomial Regression Model seems to be the best model.

# %% [markdown]
# # MY WORK

# %% [markdown]
# # Countrys with Maximum cases

# %%
df = df_orig.copy()
country = df['Country/Region'].unique()
total_country_cases = {}
for i in country:
  total_country_cases[i] = df[df['Country/Region']==i]['Confirmed'].sum()
total_country_cases
# Out:
# {' Azerbaijan': 1.0,
#  "('St. Martin',)": 2.0,
#  'Afghanistan': 1225.0,
#  'Albania': 2232.0,
#  'Algeria': 4828.0,
#  'Andorra': 2787.0,
#  'Angola': 48.0,
#  'Antigua and Barbuda': 61.0,
#  'Argentina': 6494.0,
#  'Armenia': 4099.0,
#  'Aruba': 19.0,
#  'Australia': 36147.0,
#  'Austria': 84819.0,
#  'Azerbaijan': 1915.0,
#  'Bahamas': 86.0,
#  'Bahamas, The': 10.0,
#  'Bahrain': 7926.0,
#  'Bangladesh': 546.0,
#  'Barbados': 255.0,
#  'Belarus': 1467.0,
#  'Belgium': 89035.0,
#  'Belize': 18.0,
#  'Benin': 68.0,
#  'Bhutan': 46.0,
#  'Bolivia': 682.0,
#  'Bosnia and Herzegovina': 2822.0,
#  'Botswana': 7.0,
#  'Brazil': 37132.0,
#  'Brunei': 1688.0,
#  'Bulgaria': 3576.0,
#  'Burkina Faso': 1901.0,
#  'Burma': 55.0,
#  'Burundi': 2.0,
#  'Cabo Verde': 49.0,
#  'Cambodia': 1259.0,
#  'Cameroon': 1067.0,
#  'Canada': 52258.0,
#  'Cape Verde': 1.0,
#  'Cayman Islands': 3.0,
#  'Central African Republic': 41.0,
#  'Chad': 35.0,
#  'Channel Islands': 1.0,
#  'Chile': 17663.0,
#  'Colombia': 6132.0,
#  'Congo (Brazzaville)': 97.0,
#  'Congo (Kinshasa)': 642.0,
#  'Costa Rica': 2987.0,
#  'Croatia': 6422.0,
#  'Cuba': 1020.0,
#  'Curacao': 2.0,
#  'Cyprus': 2089.0,
#  'Czech Republic': 25984.0,
#  'Denmark': 32714.0,
#  'Diamond Princess': 4984.0,
#  'Djibouti': 125.0,
#  'Dominica': 79.0,
#  'Dominican Republic': 6140.0,
#  'East Timor': 1.0,
#  'Ecuador': 16469.0,
#  'Egypt': 7156.0,
#  'El Salvador': 156.0,
#  'Equatorial Guinea': 130.0,
#  'Eritrea': 65.0,
#  'Estonia': 7353.0,
#  'Eswatini': 75.0,
#  'Ethiopia': 203.0,
#  'Faroe Islands': 10.0,
#  'Fiji': 47.0,
#  'Finland': 13419.0,
#  'France': 410165.0,
#  'French Guiana': 117.0,
#  'Gabon': 86.0,
#  'Gambia': 30.0,
#  'Gambia, The': 4.0,
#  'Georgia': 1260.0,
#  'Germany': 588757.0,
#  'Ghana': 1146.0,
#  'Gibraltar': 7.0,
#  'Greece': 13409.0,
#  'Greenland': 3.0,
#  'Grenada': 52.0,
#  'Guadeloupe': 187.0,
#  'Guam': 6.0,
#  'Guatemala': 333.0,
#  'Guernsey': 3.0,
#  'Guinea': 104.0,
#  'Guinea-Bissau': 26.0,
#  'Guyana': 140.0,
#  'Haiti': 96.0,
#  'Holy See': 54.0,
#  'Honduras': 818.0,
#  'Hong Kong': 9626.0,
#  'Hungary': 3512.0,
#  'Iceland': 11300.0,
#  'India': 10338.0,
#  'Indonesia': 11971.0,
#  'Iran': 527564.0,
#  'Iraq': 6369.0,
#  'Ireland': 23309.0,
#  'Israel': 34856.0,
#  'Italy': 1211089.0,
#  'Ivory Coast': 1052.0,
#  'Jamaica': 382.0,
#  'Japan': 30425.0,
#  'Jersey': 6.0,
#  'Jordan': 2421.0,
#  'Kazakhstan': 1935.0,
#  'Kenya': 370.0,
#  'Kosovo': 562.0,
#  'Kuwait': 4325.0,
#  'Kyrgyzstan': 587.0,
#  'Laos': 50.0,
#  'Latvia': 3277.0,
#  'Lebanon': 5181.0,
#  'Liberia': 41.0,
#  'Libya': 33.0,
#  'Liechtenstein': 694.0,
#  'Lithuania': 3611.0,
#  'Luxembourg': 17210.0,
#  'MS Zaandam': 8.0,
#  'Macau': 885.0,
#  'Madagascar': 271.0,
#  'Mainland China': 4176244.0,
#  'Malaysia': 28203.0,
#  'Maldives': 289.0,
#  'Mali': 106.0,
#  'Malta': 1707.0,
#  'Martinique': 172.0,
#  'Mauritania': 46.0,
#  'Mauritius': 841.0,
#  'Mayotte': 21.0,
#  'Mexico': 6926.0,
#  'Moldova': 2328.0,
#  'Monaco': 434.0,
#  'Mongolia': 150.0,
#  'Montenegro': 701.0,
#  'Morocco': 3758.0,
#  'Mozambique': 56.0,
#  'Namibia': 97.0,
#  'Nepal': 92.0,
#  'Netherlands': 102001.0,
#  'New Zealand': 3639.0,
#  'Nicaragua': 33.0,
#  'Niger': 119.0,
#  'Nigeria': 845.0,
#  'North Ireland': 1.0,
#  'North Macedonia': 2473.0,
#  'Norway': 51349.0,
#  'Oman': 1722.0,
#  'Others': 26228.0,
#  'Pakistan': 15587.0,
#  'Palestine': 86.0,
#  'Panama': 7285.0,
#  'Papua New Guinea': 12.0,
#  'Paraguay': 546.0,
#  'Peru': 7702.0,
#  'Philippines': 11535.0,
#  'Poland': 16224.0,
#  'Portugal': 46919.0,
#  'Puerto Rico': 3.0,
#  'Qatar': 10293.0,
#  'Republic of Ireland': 21.0,
#  'Republic of the Congo': 1.0,
#  'Reunion': 137.0,
#  'Romania': 14742.0,
#  'Russia': 12274.0,
#  'Rwanda': 579.0,
#  'Saint Barthelemy': 17.0,
#  'Saint Kitts and Nevis': 25.0,
#  'Saint Lucia': 66.0,
#  'Saint Vincent and the Grenadines': 18.0,
#  'San Marino': 3464.0,
#  'Saudi Arabia': 12266.0,
#  'Senegal': 1444.0,
#  'Serbia': 5865.0,
#  'Seychelles': 111.0,
#  'Sierra Leone': 1.0,
#  'Singapore': 13124.0,
#  'Slovakia': 3440.0,
#  'Slovenia': 8609.0,
#  'Somalia': 29.0,
#  'South Africa': 10173.0,
#  'South Korea': 257018.0,
#  'Spain': 742532.0,
#  'Sri Lanka': 1505.0,
#  'St. Martin': 2.0,
#  'Sudan': 53.0,
#  'Suriname': 88.0,
#  'Sweden': 43918.0,
#  'Switzerland': 155137.0,
#  'Syria': 52.0,
#  'Taiwan': 4545.0,
#  'Tanzania': 163.0,
#  'Thailand': 14506.0,
#  'The Bahamas': 3.0,
#  'The Gambia': 1.0,
#  'Timor-Leste': 10.0,
#  'Togo': 278.0,
#  'Trinidad and Tobago': 757.0,
#  'Tunisia': 2476.0,
#  'Turkey': 58776.0,
#  'UK': 165726.0,
#  'US': 1087452.0,
#  'Uganda': 211.0,
#  'Ukraine': 3064.0,
#  'United Arab Emirates': 5795.0,
#  'Uruguay': 2703.0,
#  'Uzbekistan': 1062.0,
#  'Vatican City': 4.0,
#  'Venezuela': 1296.0,
#  'Vietnam': 2930.0,
#  'West Bank and Gaza': 617.0,
#  'Zambia': 194.0,
#  'Zimbabwe': 53.0,
#  'occupied Palestinian territory': 25.0}

# %%
total_country_cases = sorted(total_country_cases.items(),key=lambda x:x[1] , reverse=True)
total_country_cases = dict(total_country_cases)

# %%
plt.figure(figsize=(60,10))
plt.bar(total_country_cases.keys(),total_country_cases.values())
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# we can observe that the most effected country by corna is **china**
#
# The order of first six countrys which have more conformed cases in descending order are
#
# 1) China
#
# 2) Italy
#
# 3) Spain
#
# 4) Germany
#
# 5) Iran
#
# 6) France

# %% [markdown]
# # Places Having more Conformed cases in China

# %%
states_china = df[df['Country/Region']=='Mainland China']['Province/State'].unique()

# %%
states_china
d={}
d1={}
for i in states_china:
  d[i] = df[df['Province/State']==i]['Confirmed'].cumsum()
  d1[i]= df[df['Province/State']==i]['Confirmed'].max()

for i in d:
  plt.plot(d[i])
  plt.xlabel('{}'.format(i))
  # plt.legend()
  plt.show()
# print(d)
# plt.plot(d["Anhui"])
# plt.show()

# %%
plt.figure(figsize=(10,10))
plt.bar(d1.keys(),d1.values())
plt.xlabel("states/proviance in China",size=15)
plt.ylabel("NO.of Conformed Cases",size=15)
plt.xticks(rotation=90)
plt.show()
# list(d1.items())

# %% [markdown]
# WE can see that **Hubei** state of china has more conformed cases
#
# so we need to keep more attemntion on **Hubei state of china**

# %%
# Out:
# dict_keys(['Anhui', 'Beijing', 'Chongqing', 'Fujian', 'Gansu', 'Guangdong', 'Guangxi', 'Guizhou', 'Hainan', 'Hebei', 'Heilongjiang', 'Henan', 'Hubei', 'Hunan', 'Inner Mongolia', 'Jiangsu', 'Jiangxi', 'Jilin', 'Liaoning', 'Ningxia', 'Qinghai', 'Shaanxi', 'Shandong', 'Shanghai', 'Shanxi', 'Sichuan', 'Tianjin', 'Tibet', 'Xinjiang', 'Yunnan', 'Zhejiang'])

# %%
s = df[df['Province/State']=='Anhui']['Confirmed']
d['Anhui']
# Out:
# 0            1.0
# 38          10.0
# 95          25.0
# 131         64.0
# 176        124.0
#           ...
# 9293     51607.0
# 9602     52597.0
# 9913     53587.0
# 10225    54577.0
# 10538    55567.0
# Name: Confirmed, Length: 70, dtype: float64

# %%
s.cumsum()
# Out:
# 0            1.0
# 38          10.0
# 95          25.0
# 131         64.0
# 176        124.0
#           ...
# 9293     51607.0
# 9602     52597.0
# 9913     53587.0
# 10225    54577.0
# 10538    55567.0
# Name: Confirmed, Length: 70, dtype: float64

# %% [markdown]
# # Now we are going to Find Death rate
#
# Death rate = $ \frac{total \hspace{0.2em} no.of \hspace{0.2em} death \hspace{0.2em} during \hspace{0.2em}a \hspace{0.2em} peroid}{no.of \hspace{0.2em}  people effected \hspace{0.2em} during \hspace{0.2em}  a \hspace{0.2em} peroid} $

# %%
df
# Out:
#          SNo ObservationDate Province/State  Country/Region  \
# 0          1      01/22/2020          Anhui  Mainland China
# 1          2      01/22/2020        Beijing  Mainland China
# 2          3      01/22/2020      Chongqing  Mainland China
# 3          4      01/22/2020         Fujian  Mainland China
# 4          5      01/22/2020          Gansu  Mainland China
# ...      ...             ...            ...             ...
# 10666  10667      03/31/2020        Wyoming              US
# 10667  10668      03/31/2020       Xinjiang  Mainland China
# 10668  10669      03/31/2020          Yukon          Canada
# 10669  10670      03/31/2020         Yunnan  Mainland China
# 10670  10671      03/31/2020       Zhejiang  Mainland China
#
#                Last Update  Confirmed  Deaths  Recovered
# 0          1/22/2020 17:00        1.0     0.0        0.0
# 1          1/22/2020 17:00       14.0     0.0        0.0
# 2          1/22/2020 17:00        6.0     0.0        0.0
# 3          1/22/2020 17:00        1.0     0.0        0.0
# 4          1/22/2020 17:00        0.0     0.0        0.0
# ...                    ...        ...     ...        ...
# 10666  2020-03-31 23:49:27      109.0     0.0        0.0
# 10667  2020-03-31 23:49:27       76.0     3.0       73.0
# 10668  2020-03-31 23:49:27        5.0     0.0        0.0
# 10669  2020-03-31 23:49:27      182.0     2.0      172.0
# 10670  2020-03-31 23:49:27     1257.0     1.0     1226.0
#
# [10671 rows x 8 columns]

# %%
death_rate={}
countrys = df['Country/Region'].unique()
for i in countrys:
  total = df[df['Country/Region']==i]['Confirmed'].cumsum().max()
  death = df[df['Country/Region']==i]['Deaths'].cumsum().max()
  death_rate[i]=int((death/total)*100)

# %%
death_rate = sorted(death_rate.items(),reverse=True,key=lambda x:x[1])
death_rate = dict(death_rate)

# %%
plt.figure(figsize=(50,10))
plt.bar(death_rate.keys(),death_rate.values())
plt.xticks(rotation=90)
plt.xlabel('Countrys across world effected by corona')
plt.ylabel('Death Rate in %')
plt.show()

# %% [markdown]
# we can observe that the **Sudan** country has highes death rate(40) when compare to other countrys
# Top five death rate countrys are
#
# 1) Sudan
#
# 2) Gambia
#
# 3) Zimbabwe
#
# 4) Cabo Verde
#
# 5) Nicaraguda

# %% [markdown]
# # Recovery Rate Of Countrys
#
# $ Recovery rate = 100 - death_rate(in percentage)

# %%
recovery_rate={}
countrys = df['Country/Region'].unique()
for i in countrys:
  total = df[df['Country/Region']==i]['Confirmed'].cumsum().max()
  if total==0:
    continue
  death = df[df['Country/Region']==i]['Deaths'].cumsum().max()
  recovery_rate[i]=(1-(death/total))*100

# %%
recovery_rate = sorted(recovery_rate.items(),reverse=True,key=lambda x:x[1])
recovery_rate = dict(recovery_rate)

# %%
plt.figure(figsize=(50,10))
plt.bar(recovery_rate.keys(),recovery_rate.values())
plt.xticks(rotation=90)
plt.xlabel('Countrys across world effected by corona')
plt.ylabel('Recovery Rate in %')
plt.show()

# %% [markdown]
# we can observe that the Recovery rate of some countrys are 100%(no death due to corna)
# Top five having highest recovery rate
#
# 1) Macau
#
# 2) Vietnam
#
# 3) Nepal
#
# 4) Cambodia
#
# 5) Kuwait

# %%
recovery_rate.keys()
# Out:
# dict_keys(['Macau', 'Vietnam', 'Nepal', 'Cambodia', 'Kuwait', 'Georgia', ' Azerbaijan', 'North Ireland', 'Latvia', 'Senegal', 'Saint Barthelemy', 'Faroe Islands', 'Gibraltar', 'Liechtenstein', 'Palestine', 'Bhutan', 'Vatican City', 'French Guiana', 'Malta', 'Republic of Ireland', 'Maldives', 'St. Martin', 'occupied Palestinian territory', "('St. Martin',)", 'Channel Islands', 'Holy See', 'Mongolia', 'Reunion', 'Cayman Islands', 'Guadeloupe', 'Ethiopia', 'Guinea', 'Antigua and Barbuda', 'Aruba', 'Jersey', 'Namibia', 'Seychelles', 'Curacao', 'Eswatini', 'Guernsey', 'Rwanda', 'Saint Lucia', 'Saint Vincent and the Grenadines', 'Suriname', 'Central African Republic', 'Congo (Brazzaville)', 'Equatorial Guinea', 'Guam', 'Puerto Rico', 'Benin', 'Greenland', 'Liberia', 'Mayotte', 'Republic of the Congo', 'Somalia', 'The Bahamas', 'Barbados', 'The Gambia', 'Kyrgyzstan', 'Zambia', 'Djibouti', 'Gambia, The', 'Bahamas, The', 'Chad', 'Fiji', 'Madagascar', 'Haiti', 'Papua New Guinea', 'Cape Verde', 'East Timor', 'Eritrea', 'Uganda', 'Bahamas', 'Dominica', 'Grenada', 'Mozambique', 'Timor-Leste', 'Belize', 'Laos', 'Libya', 'Guinea-Bissau', 'Saint Kitts and Nevis', 'MS Zaandam', 'Burundi', 'Sierra Leone', 'Qatar', 'Oman', 'Belarus', 'New Zealand', 'Uruguay', 'Slovakia', 'South Africa', 'Estonia', 'Singapore', 'Brunei', 'Iceland', 'Israel', 'Chile', 'Ivory Coast', 'Armenia', 'Saudi Arabia', 'Sri Lanka', 'Czech Republic', 'Russia', 'Norway', 'Thailand', 'Finland', 'Kazakhstan', 'Bahrain', 'Australia', 'United Arab Emirates', 'Croatia', 'Tanzania', 'Jordan', 'El Salvador', 'Germany', 'Monaco', 'Others', 'Austria', 'Costa Rica', 'Pakistan', 'Uzbekistan', 'Venezuela', 'Moldova', 'Malaysia', 'Luxembourg', 'Slovenia', 'West Bank and Gaza', 'South Korea', 'Kosovo', 'Canada', 'Colombia', 'Serbia', 'Ireland', 'Lithuania', 'Nigeria', 'Poland', 'Taiwan', 'Andorra', 'Diamond Princess', 'Montenegro', 'Hong Kong', 'Mexico', 'Bolivia', 'North Macedonia', 'Kenya', 'Switzerland', 'Denmark', 'Turkey', 'US', 'Portugal', 'Bosnia and Herzegovina', 'Togo', 'Burma', 'Panama', 'Peru', 'Azerbaijan', 'Cyprus', 'Bulgaria', 'Trinidad and Tobago', 'Lebanon', 'Romania', 'Sweden', 'India', 'Cameroon', 'Afghanistan', 'Argentina', 'Honduras', 'Greece', 'Ecuador', 'Tunisia', 'Brazil', 'Cuba', 'Japan', 'Ukraine', 'Mauritius', 'Ghana', 'Hungary', 'Jamaica', 'Mainland China', 'Martinique', 'Belgium', 'Dominican Republic', 'Albania', 'Mauritania', 'Burkina Faso', 'Mali', 'Egypt', 'Paraguay', 'Guatemala', 'Morocco', 'France', 'UK', 'Netherlands', 'Philippines', 'Congo (Kinshasa)', 'Iran', 'Algeria', 'Spain', 'Iraq', 'Indonesia', 'Bangladesh', 'San Marino', 'Niger', 'Syria', 'Italy', 'Angola', 'Gabon', 'Botswana', 'Guyana', 'Nicaragua', 'Cabo Verde', 'Zimbabwe', 'Gambia', 'Sudan'])
