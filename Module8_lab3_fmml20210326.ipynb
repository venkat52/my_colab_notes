# %% [markdown]
# <a href="https://colab.research.google.com/github/venkat52/my_colab_notes/blob/main/Module8_lab3_fmml20210326.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2022-06-13 15:51:54--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   276MB/s    in 0.3s
#
# 2022-06-13 15:51:55 (276 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 29779  1710.05956v3  Neonatal brain segmentation in magnetic resona...    cs
# 24642   1409.7818v2  Biometric-based identification has drawn a lot...    cs
# 6548   1703.02528v1  While the costs of human violence have attract...  stat
# 6729   1705.08736v1  We propose non-stationary spectral kernels for...  stat
# 37891   1103.1761v3  Inference in popular nonparametric Bayesian mo...  stat
# ...             ...                                                ...   ...
# 11890  1703.05160v1  Log-linear models are arguably the most succes...  stat
# 22182  1506.09068v2  Factorized Information Criterion (FIC) is a re...  stat
# 1049   1610.06258v3  Until recently, research on artificial neural ...  stat
# 13123  1610.02987v2  We propose a methodology for testing linear hy...  stat
# 15564  1509.06053v1  Text classification is a widely studied proble...    cs
#
#                                                    title  year  \
# 29779  Isointense Infant Brain Segmentation with a Hy...  2017
# 24642  On The Power of Joint Wavelet-DCT Features for...  2014
# 6548   Stopping GAN Violence: Generative Unadversaria...  2017
# 6729                     Non-Stationary Spectral Kernels  2017
# 37891  A Kernel Approach to Tractable Bayesian Nonpar...  2011
# ...                                                  ...   ...
# 11890  A New Unbiased and Efficient Class of LSH-Base...  2017
# 22182  On the Equivalence of Factorized Information C...  2015
# 1049     Using Fast Weights to Attend to the Recent Past  2016
# 13123  Linear Hypothesis Testing in Dense High-Dimens...  2016
# 15564        Early text classification: a Naive solution  2015
#
#                                                 keywords
# 29779  [segmentation, resonance, challenging, approac...
# 24642  [biometric, identification, attention, biometr...
# 6548   [attracted, attention, community, popularised,...
# 6729   [stationary, regression, stationary, dependent...
# 37891  [inference, nonparametric, typically, approxim...
# ...                                                  ...
# 11890  [successful, graphical, applications, simplici...
# 22182  [factorized, information, criterion, developed...
# 1049   [artificial, restricted, activities, represent...
# 13123  [methodology, hypothesis, dimensional, restric...
# 15564  [classification, considered, circumstances, sc...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 29779    [segmentation, resonance, challenging, approac...
# 24642    [biometric, identification, attention, biometr...
# 6548     [attracted, attention, community, popularised,...
# 6729     [stationary, regression, stationary, dependent...
# 37891    [inference, nonparametric, typically, approxim...
#                                ...
# 6263     [detection, multivariate, maximizing, divergen...
# 26936    [effective, understanding, segmentation, chall...
# 3376     [gradually, capabilities, assumption, availabl...
# 40099    [streaming, computing, especially, traditional...
# 8926     [different, approaches, different, information...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8794 words.
# Out of those 4510 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="ad5a9573-12e6-4cbf-81b8-41be9b7410ba" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ad5a9573-12e6-4cbf-81b8-41be9b7410ba")) {                    Plotly.newPlot(                        "ad5a9573-12e6-4cbf-81b8-41be9b7410ba",                        [{"x":["challenge","important","separated","alternative","connected","convolutional","supervision","sensitive","translating","processed","segmentation","different","connectivity","competitive","approaches","evaluated","independently","improving","isointense","consuming","registration","connections","strategies","performance","obtaining","including","challenging","difference","resonance","perfectly","classification","biometrics","outperforming","algorithm","identification","introduced","conditions","recognition","attention","dimensionality","multispectral","biometric","framework","grammatical","aggression","financial","experiments","published","community","generator","adversarial","anonymous","proposing","generative","distribution","addressed","carefully","likelihood","attracted","differences","simultaneously","theoretically","geospatial","characteristics","modelling","stationary","efficient","inference","generalised","transform","potentially","whitening","necessary","covariances","frequency","posterior","regression","monotonic","dependent","marginalized","nonparametric","tractable","methodology","potential","estimation","considered","approximations","literature","constructing","parametric","intuitive","nonparametrics","demonstrate","typically","explicitly","disentanglement","autoencoder","independent","parameter","behaviour","enforcing","disentangled","autoencoders","extension","variational","predictable","consequences","interpretable","underlying","introducing","representations","discriminative","existence","controlling","consistent","establish","quantifying","available","generation","variations","consequently","clustering","influence","technique","combinations","presenting","amplitude","statistical","interestingly","therefore","presented","outperforms","structure","comprehensive","experimental","techniques","effectively","contributes","consideration","topological","algorithms","represented","transformation","functions","constructed","detection","improvements","representative","meanwhile","initialize","unavailability","optimizing","formulate","encourages","sufficient","understanding","modalities","capturing","information","auxiliary","effectiveness","significant","analyzing","difficulty","predicted","assumption","invariant","asymmetry","confounder","generating","calculate","dimensional","coefficient","covariance","confounding","synthetic","optimization","influencing","inclusion","parameters","operation","characterizing","continuous","behaviors","distributions","relations","determine","quadratic","exploited","minimizing","regardless","reference","computational","asymptotic","efficiency","dimensions","discrepancy","associated","concerning","conjecture"],"y":[164,341,11,106,65,377,59,56,19,25,221,693,32,111,409,130,44,108,3,30,25,56,91,901,38,267,280,73,18,5,506,12,32,823,96,134,122,352,172,56,10,17,548,19,1,14,575,36,76,22,113,3,18,124,212,34,26,71,18,51,112,40,1,98,45,25,421,224,3,62,39,2,83,2,57,26,112,11,78,2,16,39,76,143,203,114,44,121,36,38,28,1,569,124,74,2,25,125,125,36,10,3,23,81,54,8,13,23,125,64,245,94,36,17,70,51,10,323,158,63,37,143,59,237,32,11,6,166,16,137,177,259,330,65,357,382,99,4,26,22,606,77,57,226,65,329,123,33,16,7,2,45,64,11,67,132,33,31,660,32,192,245,64,42,33,70,63,5,0,114,20,167,30,17,0,118,334,5,7,232,48,17,115,25,116,95,73,39,34,41,12,48,304,20,164,42,12,116,16,14],"type":"bar"},{"x":["challenge","important","separated","alternative","connected","convolutional","sup ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4510,), (4510, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8166666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Optical</span> <span style=''>Flow</span> <span style=''>Guided</span> <span style=''>Feature</span> <span style=''>A</span> <span style=''>Fast</span> <span style=''>and</span> <span style=''>Robust</span> <span style=''>Motion</span> <span style='background-color:rgba(0, 255, 0, 0.3984375000000001);'>Representation</span> <span style=''>for</span> <span style=''>Video</span> <span style=''>Action</span> <span style='background-color:rgba(0, 255, 0, 0.5784753363228701);'>Recognition</span> <br/><br/><span style=''>Motion</span> <span style='background-color:rgba(0, 255, 0, 0.3984375000000001);'>representation</span> <span style=''>plays</span> <span style=''>a</span> <span style=''>vital</span> <span style=''>role</span> <span style=''>in</span> <span style=''>human</span> <span style=''>action</span> <span style='background-color:rgba(0, 255, 0, 0.5784753363228701);'>recognition</span> <span style=''>in</span> <span style=''>videos</span> <span style=''>In</span> <span style=''>this</span> <span style=''>study</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>compact</span> <span style=''>motion</span> <span style='background-color:rgba(0, 255, 0, 0.3984375000000001);'>representation</span> <span style=''>for</span> <span style=''>video</span> <span style=''>action</span> <span style='background-color:rgba(0, 255, 0, 0.5784753363228701);'>recognition</span> <span style=''>named</span> <span style=''>Optical</span> <span style=''>Flow</span> <span style=''>guided</span> <span style=''>Feature</span> <span style=''>(OFF)</span> <span style=''>which</span> <span style=''>enables</span> <span style=''>the</span> <span style=''>network</span> <span style=''>to</span> <span style=''>distill</span> <span style=''>temporal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style=''>through</span> <span style=''>a</span> <span style=''>fast</span> <span style=''>and</span> <span style=''>robust</span> <span style=''>approach</span> <span style=''>The</span> <span style=''>OFF</span> <span style=''>is</span> <span style=''>derived</span> <span style=''>from</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3432835820895522);'>definition</span> <span style=''>of</span> <span style=''>optical</span> <span style=''>flow</span> <span style=''>and</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>orthogonal</span> <span style=''>to</span> <span style=''>the</span> <span style=''>optical</span> <span style=''>flow</span> <span style=''>By</span> <span style=''>directly</span> <span style='background-color:rgba(0, 255, 0, 0.6190476190476191);'>calculating</span> <span style=''>pixel</span> <span style=''>wise</span> <span style=''>spatio</span> <span style=''>temporal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>gradients</span> <span style=''>of</span> <span style=''>the</span> <span style=''>deep</span> <span style=''>feature</span> <span style=''>maps</span> <span style=''>the</span> <span style=''>OFF</span> <span style=''>could</span> <span style=''>be</span> <span style=''>embedded</span> <span style=''>in</span> <span style=''>any</span> <span style=''>existing</span> <span style=''>CNN</span> <span style=''>based</span> <span style=''>video</span> <span style=''>action</span> <span style='background-color:rgba(0, 255, 0, 0.5784753363228701);'>recognition</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>with</span> <span style=''>only</span> <span style=''>a</span> <span style=''>slight</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>additional</span> <span style=''>cost</span> <span style=''>It</span> <span style=''>enables</span> <span style=''>the</span> <span style=''>CNN</span> <span style=''>to</span> <span style=''>extract</span> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Multi</span> <span style=''>Horizon</span> <span style=''>Quantile</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Recurrent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Forecaster</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>for</span> <span style=''>general</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>multi</span> <span style=''>step</span> <span style=''>time</span> <span style=''>series</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Specifically</span> <span style=''>we</span> <span style=''>exploit</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expressiveness</span> <span style=''>and</span> <span style=''>temporal</span> <span style=''>nature</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Recurrent</span> <span style=''>Neural</span> <span style=''>Networks</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonparametric</span> <span style=''>nature</span> <span style=''>of</span> <span style=''>Quantile</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Regression</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficiency</span> <span style=''>of</span> <span style=''>Direct</span> <span style=''>Multi</span> <span style=''>Horizon</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Forecasting</span> <span style=''>A</span> <span style=''>new</span> <span style=''>training</span> <span style=''>scheme</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recurrent</span> <span style=''>nets</span> <span style=''>is</span> <span style=''>designed</span> <span style=''>to</span> <span style=''>boost</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stability</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>approach</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>accommodates</span> <span style=''>both</span> <span style=''>temporal</span> <span style=''>and</span> <span style=''>static</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariates</span> <span style=''>learning</span> <span style=''>across</span> <span style=''>multiple</span> <span style=''>related</span> <span style=''>series</span> <span style=''>shifting</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>seasonality</span> <span style=''>future</span> <span style=''>planned</span> <span style=''>event</span> <span style=''>spikes</span> <span style=''>and</span> <span style=''>cold</span> <span style=''>starts</span> <span style=''>in</span> <span style=''>real</span> <span style=''>life</span> <span style=''>large</span> <span style=''>scale</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>forecasting</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrated</span> <span style=''>in</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>application</span> <span style=''>to</span> <span style=''>predict</span> <span style=''>the</span> <span style=''>future</span> <span style=''>demand</span> <span style=''>of</span> <span style=''>items</span> <span style=''>sold</span> <span style=''>on</span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Optimal</span> <span style=''>Margin</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Distribution</span> <span style=''>Machine</span> <br/><br/><span style=''>Support</span> <span style=''>vector</span> <span style=''>machine</span> <span style=''>(SVM)</span> <span style=''>has</span> <span style=''>been</span> <span style=''>one</span> <span style=''>of</span> <span style=''>the</span> <span style=''>most</span> <span style=''>popular</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>with</span> <span style=''>the</span> <span style=''>central</span> <span style=''>idea</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>maximizing</span> <span style=''>the</span> <span style=''>minimum</span> <span style=''>margin</span> <span style=''>ie</span> <span style=''>the</span> <span style=''>smallest</span> <span style=''>distance</span> <span style=''>from</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3191489361702128);'>instances</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>boundary</span> <span style=''>Recent</span> <span style='background-color:rgba(255, 0, 0, 0.33050847457627114);'>theoretical</span> <span style=''>results</span> <span style=''>however</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333334);'>disclosed</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>maximizing</span> <span style=''>the</span> <span style=''>minimum</span> <span style=''>margin</span> <span style=''>does</span> <span style=''>not</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>necessarily</span> <span style=''>lead</span> <span style=''>to</span> <span style=''>better</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performances</span> <span style=''>and</span> <span style=''>instead</span> <span style=''>the</span> <span style=''>margin</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>has</span> <span style=''>been</span> <span style=''>proven</span> <span style=''>to</span> <span style=''>be</span> <span style=''>more</span> <span style=''>crucial</span> <span style=''>Based</span> <span style=''>on</span> <span style=''>this</span> <span style=''>idea</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style=''>method</span> <span style=''>named</span> <span style=''>Optimal</span> <span style=''>margin</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Distribution</span> <span style=''>Machine</span> <span style=''>(ODM)</span> <span style=''>which</span> <span style=''>tries</span> <span style=''>to</span> <span style=''>achieve</span> <span style=''>a</span> <span style=''>better</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimizing</span> <span style=''>the</span> <span style=''>margin</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>characterize</span> <span style=''>the</span> <span style=''>margin</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>by</span> <span style=''>the</span> <span style=''>first</span> <span style=''>and</span> <span style=''>second</span> <span style=''>order</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>statistics</span> <span style=''>ie</span> <span style=''>the</span> <span style=''>margin</span> <span style=''>mea ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Interpretable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Predictions</span> <span style=''>of</span> <span style=''>Tree</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Ensembles</span> <span style=''>via</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Actionable</span> <span style=''>Feature</span> <span style=''>Tweaking</span> <br/><br/><span style=''>Machine</span> <span style=''>learned</span> <span style=''>models</span> <span style=''>are</span> <span style=''>often</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>described</span> <span style=''>as</span> <span style=''>black</span> <span style=''>boxes</span> <span style=''>In</span> <span style=''>many</span> <span style=''>real</span> <span style=''>world</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>however</span> <span style=''>models</span> <span style=''>may</span> <span style=''>have</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sacrifice</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictive</span> <span style=''>power</span> <span style=''>in</span> <span style=''>favour</span> <span style=''>of</span> <span style=''>human</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretability</span> <span style=''>When</span> <span style=''>this</span> <span style=''>is</span> <span style=''>the</span> <span style=''>case</span> <span style=''>feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>engineering</span> <span style=''>becomes</span> <span style=''>a</span> <span style=''>crucial</span> <span style=''>task</span> <span style=''>which</span> <span style=''>requires</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significant</span> <span style=''>and</span> <span style=''>time</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consuming</span> <span style=''>human</span> <span style=''>effort</span> <span style=''>Whilst</span> <span style=''>some</span> <span style=''>features</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inherently</span> <span style=''>static</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>that</span> <span style=''>cannot</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>influenced</span> <span style=''>(eg</span> <span style=''>the</span> <span style=''>age</span> <span style=''>of</span> <span style=''>an</span> <span style=''>individual)</span> <span style=''>others</span> <span style=''>capture</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>characteristics</span> <span style=''>that</span> <span style=''>could</span> <span style=''>be</span> <span style=''>adjusted</span> <span style=''>(eg</span> <span style=''>the</span> <span style=''>daily</span> <span style=''>amount</span> <span style=''>of</span> <span style=''>carbohydrates</span> <span style=''>taken)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Nonetheless</span> <span style=''>once</span> <span style=''>a</span> <span style=''>model</span> <span style=''>is</span> <span style=''>learned</span> <span style=''>from</span> <span style=''>the</span> <span style=''>data</span> <span style=''>each</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>it</span> <span style=''>makes</span> <span style=''>on</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>instances</span> <span style=''>is</span> <span style=''>irreversible</span> <span style=''>assuming</span> <span style=''>every</span> <span style=''>instance</span> <span style=''>to</span> <span style=''>be</span> <span style=''>a</span> <span style=''>sta ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	information (0.23605150214592274)
# 	representation (0.12804005722460657)
# 	knowledge (0.11909871244635194)
# 	evaluation (0.10121602288984263)
# 	architecture (0.09155937052932761)
# 	segmentation (0.07904148783977111)
# 	different (0.2478540772532189)
# 	detection (0.11766809728183118)
# 	recognition (0.12589413447782546)
# 	convolutional (0.1348354792560801)
#
# Some Statistics words are:
# 	stochastic (0.12674650698602793)
# 	variables (0.13672654690618763)
# 	algorithm (0.3842315369261477)
# 	statistical (0.15169660678642716)
# 	estimation (0.17265469061876249)
# 	theoretical (0.156686626746507)
# 	distribution (0.18063872255489022)
# 	inference (0.19510978043912175)
# 	dimensional (0.18662674650698602)
# 	regression (0.18413173652694612)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="c15f0c6f-6da0-4190-96f4-3e6b68c8bc0d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c15f0c6f-6da0-4190-96f4-3e6b68c8bc0d")) {                    Plotly.newPlot(                        "c15f0c6f-6da0-4190-96f4-3e6b68c8bc0d",                        [{"x":["challenge","important","separated","alternative","connected","convolutional","supervision","sensitive","translating","processed","segmentation","different","connectivity","competitive","approaches","evaluated","independently","improving","isointense","consuming","registration","connections","strategies","performance","obtaining","including","challenging","difference","resonance","perfectly","classification","biometrics","outperforming","algorithm","identification","introduced","conditions","recognition","attention","dimensionality","multispectral","biometric","framework","grammatical","aggression","financial","experiments","published","community","generator","adversarial","anonymous","proposing","generative","distribution","addressed","carefully","likelihood","attracted","differences","simultaneously","theoretically","geospatial","characteristics","modelling","stationary","efficient","inference","generalised","transform","potentially","whitening","necessary","covariances","frequency","posterior","regression","monotonic","dependent","marginalized","nonparametric","tractable","methodology","potential","estimation","considered","approximations","literature","constructing","parametric","intuitive","nonparametrics","demonstrate","typically","explicitly","disentanglement","autoencoder","independent","parameter","behaviour","enforcing","disentangled","autoencoders","extension","variational","predictable","consequences","interpretable","underlying","introducing","representations","discriminative","existence","controlling","consistent","establish","quantifying","available","generation","variations","consequently","clustering","influence","technique","combinations","presenting","amplitude","statistical","interestingly","therefore","presented","outperforms","structure","comprehensive","experimental","techniques","effectively","contributes","consideration","topological","algorithms","represented","transformation","functions","constructed","detection","improvements","representative","meanwhile","initialize","unavailability","optimizing","formulate","encourages","sufficient","understanding","modalities","capturing","information","auxiliary","effectiveness","significant","analyzing","difficulty","predicted","assumption","invariant","asymmetry","confounder","generating","calculate","dimensional","coefficient","covariance","confounding","synthetic","optimization","influencing","inclusion","parameters","operation","characterizing","continuous","behaviors","distributions","relations","determine","quadratic","exploited","minimizing","regardless","reference","computational","asymptotic","efficiency","dimensions","discrepancy","associated","concerning","conjecture","resolution","complexity","determined","corresponding","probability","stochastic","expectation","nontrivial","classical","belonging","convolution","hyperspectral","piecewise","exploiting","direction","observation","knowledge","posedness","abundance","nonnegativity","estimator","alternating","variation","regularization","arbitrary","uniqueness","regularize","conjunction","endmember","alleviate","comparison","resultant","constraints","perturbations","abundances","multipliers","facilitates","panchromatic","approximately","preconditions","partially","processes","observable","specifically","approximated","monitoring","decisions","generally","precondition","replanning","implementation","usability","practical","languages","lookahead","structures","imp ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	confounder
# 	confounding
# 	internally
# 	scientist
# 	unobservable
# 	advocated
# 	factorizing
# 	covariates
# 	stratifying
# 	neuroimaging
# 	extrapolating
# 	regularised
# 	prioritization
# 	explodingvanishing
# 	adjustments
# 	clairvoyant
# 	changepoint
# 	accompanies
# 	reparameterized
# 	nucleotide
# Some words which never appear in Statistics papers:
# 	isointense
# 	posedness
# 	preconditions
# 	replanning
# 	specifications
# 	anaphoric
# 	discourse
# 	argumentation
# 	apparently
# 	biologists
# 	panoramas
# 	quadrotor
# 	backprojection
# 	disturbance
# 	regulated
# 	associates
# 	nonmonotonic
# 	rationality
# 	definable
# 	soundness

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.079765937788728e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7641666666666667

# %% [markdown]
# #Accuracy effect by the alpha value

# %%
counts_cs ,counts_stat
# Out:
# (array([164, 341,  11, ...,   0,   2,   2]),
#  array([ 95, 217,   9, ...,   2,   0,   0]))

# %%
alphas = [1,10,25,100]
for alpha in alphas:
  counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
  evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
  words_to_index = defaultdict(lambda: -1)
  for idx, word in enumerate(words):
      words_to_index[word] = idx

  correct, total = 0, 0

  answers = []
  for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
      this_counts = np.zeros(len(words))
      for word in keywords:
          idx = words_to_index[word]
          if idx != -1:
              this_counts[idx] = 1

      marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
      joint = np.sum(np.log(marginal), axis=0)
      predicted = 'cs' if joint[0] > joint[1] else 'stat'
      answers.append(predicted)
      if predicted == tag:
          correct += 1
      total += 1
  test_df.insert(1, "predictions", answers, True)

  print("Accuracy:", correct / total,"for ",alpha)
# Out:
# Accuracy: 0.6383333333333333 for  1
# Accuracy: 0.5958333333333333 for  10
# Accuracy: 0.59 for  25
# Accuracy: 0.5866666666666667 for  100

# %% [markdown]
# #observation
# we can see that by **increasing alpha value we are getting reduction in accuracy**. so aplha=1 is good for the model

# %% [markdown]
# # My Conclusion
# 1) we understand how to use tha navie bayes for classifcation of text
#
# 2) Also we learnt how to avoid of zero probability condition which is due to a word which is not in training set using the laplace smoothing so that it won't give zero probabilty by setting an alpha value
#
# 3) Also seen how the alpha value effects the accuracy
